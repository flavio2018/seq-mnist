# %%
import torch
from hydra import compose, initialize
import omegaconf

from model.builders import build_model
from utils.run_utils import configure_reproducibility

# %%
initialize(config_path="../conf/local", job_name="debug_dl")
cfg = compose(config_name="test_model_mnist")

# %%
cfg.run.wandb_mode='disabled'

# %%
print(omegaconf.OmegaConf.to_yaml(cfg))
# Out:
# run:
#   device: cpu
#   loglevel: INFO
#   project_path: /media/shift97/MyPassport/Flavio/repos/seq-mnist
#   codename: default_local
#   seed: 2147483647
#   wandb_mode: disabled
# data:
#   num_train: 3000
#   num_test: 10000
#   permute: true
# train:
#   batch_size: 4
#   perc_valid: 0.1
# model:
#   name: dntm
#   n_locations: 1000
#   content_size: 8
#   address_size: 8
#   controller_input_size: 1
#   controller_output_size: 10
#   controller_hidden_state_size: 100
#   ckpt: ${run.project_path}/models/checkpoints/dntm_trained_pmnist_02-06-22.pth

# %%
rng = configure_reproducibility(cfg.run.seed)

# %%
device = torch.device(cfg.run.device, 0)

# %%
model = build_model(cfg, device)

# %%
for name, param in model.named_parameters():
    print(name)
    print('-'*len(name))
    print(param.max().item())
    print(param.mean().item(), '+/-', param.std().item())
    print(param.min().item())
    print()
# Out:
# W_output
# --------
# 1.713209867477417
# -0.001367107848636806 +/- 0.37482231855392456
# -1.5997358560562134
#
# b_output
# --------
# 0.144056037068367
# 0.10458298027515411 +/- 0.02648264914751053
# 0.05537264049053192
#
# memory.memory_addresses
# -----------------------
# 0.25264522433280945
# -0.0022635748609900475 +/- 0.08650892227888107
# -0.3241351842880249
#
# memory.W_hat_hidden
# -------------------
# 0.9974824786186218
# 0.0021850443445146084 +/- 0.16166022419929504
# -0.9490581154823303
#
# memory.W_query
# --------------
# 0.5995498299598694
# 0.0016025464283302426 +/- 0.13604740798473358
# -0.5335453748703003
#
# memory.b_query
# --------------
# 0.37084341049194336
# -0.12415798008441925 +/- 0.2623516023159027
# -0.6728257536888123
#
# memory.u_sharpen
# ----------------
# 0.5539348721504211
# -0.021196791902184486 +/- 0.19362500309944153
# -0.44481608271598816
#
# memory.b_sharpen
# ----------------
# -0.05614190176129341
# -0.05614190176129341 +/- nan
# -0.05614190176129341
#
# memory.b_lru
# ------------
# 0.1679871380329132
# 0.1679871380329132 +/- nan
# 0.1679871380329132
#
# memory.u_lru
# ------------
# 0.6606274843215942
# -0.0220094732940197 +/- 0.24004556238651276
# -0.5987517237663269
#
# memory.W_erase
# --------------
# 0.7449154257774353
# -0.00163609953597188 +/- 0.16272494196891785
# -0.4764401912689209
#
# memory.b_erase
# --------------
# 0.7012081146240234
# 0.3003966212272644 +/- 0.36039191484451294
# -0.29647406935691833
#
# memory.W_content_hidden
# -----------------------
# 0.6144950985908508
# -0.0044907573610544205 +/- 0.18617519736289978
# -1.4193204641342163
#
# memory.W_content_input
# ----------------------
# 0.959353506565094
# 0.16214703023433685 +/- 0.5069385766983032
# -0.5325843095779419
#
# memory.u_input_content_alpha
# ----------------------------
# -1.232453465461731
# -1.232453465461731 +/- nan
# -1.232453465461731
#
# memory.u_hidden_content_alpha
# -----------------------------
# 0.32922786474227905
# -0.013891913928091526 +/- 0.1803225874900818
# -0.44123002886772156
#
# memory.b_content_alpha
# ----------------------
# -0.18915104866027832
# -0.18915104866027832 +/- nan
# -0.18915104866027832
#
# controller.W_ir
# ---------------
# 8.850006103515625
# 0.25616323947906494 +/- 1.0338525772094727
# -1.147384524345398
#
# controller.W_iz
# ---------------
# 1.5021358728408813
# -0.05699431523680687 +/- 0.5951500535011292
# -1.6019458770751953
#
# controller.W_in
# ---------------
# 2.9970474243164062
# 0.023306284099817276 +/- 0.9705381393432617
# -3.7086989879608154
#
# controller.b_ir
# ---------------
# 0.32011035084724426
# -0.0007307699415832758 +/- 0.18713438510894775
# -0.3919088840484619
#
# controller.b_iz
# ---------------
# 0.4667109549045563
# 0.010736840777099133 +/- 0.22843974828720093
# -0.5469053387641907
#
# controller.b_in
# ---------------
# 0.33961108326911926
# 0.004902621731162071 +/- 0.16057756543159485
# -0.36111268401145935
#
# controller.W_hr
# ---------------
# 1.098063349723816
# 0.0014342620270326734 +/- 0.21442773938179016
# -1.081673502922058
#
# controller.W_hz
# ---------------
# 1.2077609300613403
# 0.0004306262999307364 +/- 0.24712641537189484
# -1.1396467685699463
#
# controller.W_hn
# ---------------
# 1.0243092775344849
# 0.002030815463513136 +/- 0.19451704621315002
# -1.0447297096252441
#
# controller.b_hr
# ---------------
# 0.5001267790794373
# 0.00046041965833865106 +/- 0.17690560221672058
# -0.34962406754493713
#
# controller.b_hz
# ---------------
# 0.4350305497646332
# 0.014706360176205635 +/- 0.21379144489765167
# -0.43252915143966675
#
# controller.b_hn
# ---------------
# 0.2692315876483917
# -0.027645083144307137 +/- 0.1321347951889038
# -0.4154953956604004
#
# controller.W_mr
# ---------------
# 0.6805036664009094
# 0.002916566329076886 +/- 0.18663379549980164
# -0.691824197769165
#
# controller.W_mz
# ---------------
# 0.697873055934906
# -0.007547606248408556 +/- 0.21420347690582275
# -1.2681424617767334
#
# controller.W_mn
# ---------------
# 0.48192298412323
# 0.004603670910000801 +/- 0.15297268331050873
# -0.48171353340148926
#
# controller.b_mr
# ---------------
# 0.391573429107666
# -0.008244385942816734 +/- 0.16656847298145294
# -0.375507652759552
#
# controller.b_mz
# ---------------
# 0.6128559708595276
# 0.010752933099865913 +/- 0.21854552626609802
# -0.4543590247631073
#
# controller.b_mn
# ---------------
# 0.339225709438324
# 0.0032267344649881124 +/- 0.1526782512664795
# -0.3004777729511261

# %%
from data.perm_seq_mnist import get_dataloaders
from torchmetrics.classification import Accuracy

# %%
train_dl, valid_data_loader = get_dataloaders(cfg, rng)

# %%
loss_fn = torch.nn.NLLLoss()

# %%
valid_accuracy = Accuracy().to(device)
valid_epoch_loss = 0
model.eval()
for batch_i, (mnist_images, targets) in enumerate(valid_data_loader):
    print("batch", batch_i)
    model.prepare_for_batch(mnist_images, device)

    mnist_images, targets = mnist_images.to(device), targets.to(device)

    _, outputs = model(mnist_images)
    output = outputs[-1, :, :]
    print(output.T.argmax(dim=1))
    loss_value = loss_fn(output.T, targets)
    valid_epoch_loss += loss_value.item() * mnist_images.size(0)
    print("loss:", loss_value)

    batch_accuracy = valid_accuracy(output.T, targets)
valid_accuracy_at_epoch = valid_accuracy.compute()
valid_epoch_loss /= len(valid_data_loader.sampler)
print(valid_accuracy_at_epoch)
print(valid_epoch_loss)
# Out:
# batch 0
# tensor([1, 1, 1, 1])
# loss: tensor(5.7175, grad_fn=<NllLossBackward0>)
# batch 1
# tensor([1, 1, 2, 1])
# loss: tensor(6.6564, grad_fn=<NllLossBackward0>)
# batch 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       6 model.prepare_for_batch(mnist_images, device)
#       8 mnist_images, targets = mnist_images.to(device), targets.to(device)
# ---> 10 _, outputs = model(mnist_images)
#      11 output = outputs[-1, :, :]
#      12 print(output.T.argmax(dim=1))
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/.env/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachine.py:37, in DynamicNeuralTuringMachine.forward(self, input)
#      35     return self.step_on_batch_element(input)
#      36 elif len(input.shape) == 3:
# ---> 37     return self.step_on_batch(input)
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachine.py:49, in DynamicNeuralTuringMachine.step_on_batch(self, batch)
#      47 for i_seq in range(seq_len):
#      48     batch_element = batch[:, i_seq, :].reshape(feature_size, batch_size)
# ---> 49     controller_hidden_state, output = self.step_on_batch_element(batch_element)
#      50     hidden_states.append(controller_hidden_state)
#      51     outputs.append(output)
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachine.py:55, in DynamicNeuralTuringMachine.step_on_batch_element(self, x)
#      54 def step_on_batch_element(self, x):
# ---> 55     self.memory_reading = self.memory.read(self.controller_hidden_state)
#      56     # self.memory_reading = torch.zeros_like(self.memory_reading)
#      57     self.memory.update(self.controller_hidden_state, x)
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachineMemory.py:45, in DynamicNeuralTuringMachineMemory.read(self, controller_hidden_state)
#      44 def read(self, controller_hidden_state):
# ---> 45     self.read_weights = self._address_memory(controller_hidden_state)
#      46     # this implements the memory NO-OP at reading phase
#      47     return self._full_memory_view()[:-1, :].T @ self.read_weights[:-1, :]
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachineMemory.py:69, in DynamicNeuralTuringMachineMemory._address_memory(self, controller_hidden_state)
#      67 query = self.W_query.T @ projected_hidden_state + self.b_query
#      68 sharpening_beta = F.softplus(self.u_sharpen.T @ controller_hidden_state + self.b_sharpen) + 1
# ---> 69 similarity_vector = self._compute_similarity(query, sharpening_beta)
#      70 address_vector = self._apply_lru_addressing(similarity_vector, controller_hidden_state)
#      71 return address_vector
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachineMemory.py:78, in DynamicNeuralTuringMachineMemory._compute_similarity(self, query, sharpening_beta)
#      76 def _compute_similarity(self, query, sharpening_beta):
#      77     """Compute the sharpened cosine similarity vector between the query and the memory locations."""
# ---> 78     full_memory_view = self._full_memory_view()
#      79     return sharpening_beta * F.cosine_similarity(full_memory_view[:, None, :], query.T[None, :, :],
#      80                                                  eps=1e-7, dim=-1)
#
# File /media/shift97/MyPassport/Flavio/repos/seq-mnist/src/model/dntm/DynamicNeuralTuringMachineMemory.py:74, in DynamicNeuralTuringMachineMemory._full_memory_view(self)
#      73 def _full_memory_view(self):
# ---> 74     return torch.cat((self.memory_addresses, self.memory_contents), dim=1)
#
# KeyboardInterrupt:
